# %%
from sympy import *
from sympy.physics.quantum.dagger import Dagger
import numpy as np

population_zero = []
population_one = []
population_two = []

ground = np.array([
    [1], [0], [0]
])

first_excited = np.array([
    [0], [1], [0]
])

second_excited = np.array([
    [0], [0], [1]
])

def RX01(theta, epsilon):
    Rotation = np.array([
        [cos((theta+epsilon)/2), -1j*sin((theta+epsilon)/2), 0],
        [-1j*sin((theta+epsilon)/2), cos((theta+epsilon)/2), 0],
        [0, 0, 1]
    ])
    return Rotation

integer = 5
repetitions = 2*integer+1
d_range = np.linspace(1, repetitions, repetitions)
epsilon = 0.01

for d in range(repetitions):
    initial_state = np.array([[1], [0], [0]])
    Unitary = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
    for j in range(d+1):
        Unitary = RX01(pi/2, epsilon) @ Unitary
    final_state = Unitary@initial_state
    population_zero.append(np.absolute(final_state[0])**2)
    population_one.append(np.absolute(final_state[1])**2)
    population_two.append(np.absolute(final_state[2])**2)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (10, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)   

import matplotlib.pyplot as plt
plt.plot(d_range, population_zero, '--bo', label=r'$P_{|0\rangle}$')
plt.plot(d_range, population_one, '--s', color='orange', label=r'$P_{|1\rangle}$')
# plt.plot(d_range, population_two, 'g*', label=r'$P_{|2\rangle}$')
plt.legend(fontsize=15)
plt.xlabel(r"# of iteration of $\tilde{X}$, $\epsilon$ = %f" % (epsilon), fontsize=15)
plt.ylabel(r"Probabilities",fontsize=15)
# plt.xlim(40,60)
# plt.savefig('StartTc.png',dpi=128)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 34>()
#      39     final_state = Unitary@initial_state
#      40     population_zero.append(np.absolute(final_state[0])**2)
# ---> 41     population_one.append(np.absolute(final_state[1])**2)
#      42     population_two.append(np.absolute(final_state[2])**2)
#      44 import matplotlib.pylab as pylab
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/expr.py:193, in Expr.__abs__(self)
#     191 def __abs__(self) -> Expr:
#     192     from sympy.functions.elementary.complexes import Abs
# --> 193     return Abs(self)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/function.py:469, in Function.__new__(cls, *args, **options)
#     461     raise TypeError(temp % {
#     462         'name': cls,
#     463         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     464         'args': min(cls.nargs),
#     465         'plural': 's'*(min(cls.nargs) != 1),
#     466         'given': n})
#     468 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 469 result = super().__new__(cls, *args, **options)
#     470 if evaluate and isinstance(result, cls) and result.args:
#     471     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/function.py:309, in Application.__new__(cls, *args, **options)
#     306     raise ValueError("Unknown options: %s" % options)
#     308 if evaluate:
# --> 309     evaluated = cls.eval(*args)
#     310     if evaluated is not None:
#     311         return evaluated
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/functions/elementary/complexes.py:608, in Abs.eval(cls, arg)
#     605     return
#     606 # reject result if all new conjugates are just wrappers around
#     607 # an expression that was already in the arg
# --> 608 conj = signsimp(arg.conjugate(), evaluate=False)
#     609 new_conj = conj.atoms(conjugate) - arg.atoms(conjugate)
#     610 if new_conj and all(arg.has(i.args[0]) for i in new_conj):
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/simplify/simplify.py:412, in signsimp(expr, evaluate)
#     409 if e.is_Add:
#     410     rv = e.func(*[signsimp(a) for a in e.args])
#     411     if not evaluate and isinstance(rv, Add
# --> 412             ) and rv.could_extract_minus_sign():
#     413         return Mul(S.NegativeOne, -rv, evaluate=False)
#     414     return rv
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/add.py:416, in Add.could_extract_minus_sign(self)
#     415 def could_extract_minus_sign(self):
# --> 416     return _could_extract_minus_sign(self)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/add.py:33, in _could_extract_minus_sign(expr)
#      29     return True
#      30 # choose based on .sort_key() to prefer
#      31 # x - 1 instead of 1 - x and
#      32 # 3 - sqrt(2) instead of -3 + sqrt(2)
# ---> 33 return bool(expr.sort_key() < (-expr).sort_key())
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/expr.py:135, in Expr.sort_key(self, order)
#     133 else:
#     134     if expr.is_Add:
# --> 135         args = expr.as_ordered_terms(order=order)
#     136     elif expr.is_Mul:
#     137         args = expr.as_ordered_factors(order=order)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/expr.py:1146, in Expr.as_ordered_terms(self, order, data)
#    1143             return add_args
#    1145 key, reverse = self._parse_order(order)
# -> 1146 terms, gens = self.as_terms()
#    1148 if not any(term.is_Order for term, _ in terms):
#    1149     ordered = sorted(terms, key=key, reverse=reverse)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/expr.py:1183, in Expr.as_terms(self)
#    1181 if factor.is_number:
#    1182     try:
# -> 1183         coeff *= complex(factor)
#    1184     except (TypeError, ValueError):
#    1185         pass
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/expr.py:354, in Expr.__complex__(self)
#     353 def __complex__(self):
# --> 354     result = self.evalf()
#     355     re, im = result.as_real_imag()
#     356     return complex(float(re), float(im))
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1659, in EvalfMixin.evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1657     options['quad'] = quad
#    1658 try:
# -> 1659     result = evalf(self, prec + 4, options)
#    1660 except NotImplementedError:
#    1661     # Fall back to the ordinary evalf
#    1662     if hasattr(self, 'subs') and subs is not None:  # issue 20291
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in evalf_add(v, prec, options)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in <listcomp>(.0)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:698, in evalf_mul(v, prec, options)
#     696 elif i == last and arg is S.One:
#     697     continue
# --> 698 re, im, re_acc, im_acc = evalf(arg, working_prec, options)
#     699 if re and im:
#     700     complex_factors.append((re, im, re_acc, im_acc))
#
#     [... skipping similar frames: evalf at line 1496 (1 times)]
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in evalf_add(v, prec, options)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in <listcomp>(.0)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
#     [... skipping similar frames: evalf at line 1496 (1 times)]
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:698, in evalf_mul(v, prec, options)
#     696 elif i == last and arg is S.One:
#     697     continue
# --> 698 re, im, re_acc, im_acc = evalf(arg, working_prec, options)
#     699 if re and im:
#     700     complex_factors.append((re, im, re_acc, im_acc))
#
#     [... skipping similar frames: evalf at line 1496 (4 times), <listcomp> at line 602 (2 times), evalf_add at line 602 (2 times), evalf_mul at line 698 (1 times)]
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:698, in evalf_mul(v, prec, options)
#     696 elif i == last and arg is S.One:
#     697     continue
# --> 698 re, im, re_acc, im_acc = evalf(arg, working_prec, options)
#     699 if re and im:
#     700     complex_factors.append((re, im, re_acc, im_acc))
#
#     [... skipping similar frames: evalf at line 1496 (1 times)]
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in evalf_add(v, prec, options)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in <listcomp>(.0)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:650, in evalf_mul(v, prec, options)
#     648 from .numbers import Float
#     649 for arg in args:
# --> 650     result = evalf(arg, prec, options)
#     651     if result is S.ComplexInfinity:
#     652         special.append(result)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in evalf_add(v, prec, options)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in <listcomp>(.0)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:650, in evalf_mul(v, prec, options)
#     648 from .numbers import Float
#     649 for arg in args:
# --> 650     result = evalf(arg, prec, options)
#     651     if result is S.ComplexInfinity:
#     652         special.append(result)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in evalf_add(v, prec, options)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:602, in <listcomp>(.0)
#     599 while 1:
#     600     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 602     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603     n = terms.count(S.ComplexInfinity)
#     604     if n >= 2:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:650, in evalf_mul(v, prec, options)
#     648 from .numbers import Float
#     649 for arg in args:
# --> 650     result = evalf(arg, prec, options)
#     651     if result is S.ComplexInfinity:
#     652         special.append(result)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:778, in evalf_pow(v, prec, options)
#     775 # Exponentiation by p magnifies relative error by |p|, so the
#     776 # base must be evaluated with increased precision if p is large
#     777 prec += int(math.log(abs(p), 2))
# --> 778 result = evalf(base, prec + 5, options)
#     779 if result is S.ComplexInfinity:
#     780     if p < 0:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:1496, in evalf(x, prec, options)
#    1494 try:
#    1495     rf = evalf_table[type(x)]
# -> 1496     r = rf(x, prec, options)
#    1497 except KeyError:
#    1498     # Fall back to ordinary evalf if possible
#    1499     if 'subs' in options:
#
# File ~/Library/Python/3.8/lib/python/site-packages/sympy/core/evalf.py:933, in evalf_trig(v, prec, options)
#     929 # Magnitude <= 1.0. OK to compute directly, because there is no
#     930 # danger of hitting the first root of cos (with sin, magnitude
#     931 # <= 2.0 would actually be ok)
#     932 if xsize < 1:
# --> 933     return func(re, prec, rnd), None, prec, None
#     934 # Very large
#     935 if xsize >= 10:
#
# File ~/Library/Python/3.8/lib/python/site-packages/mpmath/libmp/libelefun.py:1379, in mpf_sin(x, prec, rnd)
# -> 1379 def mpf_sin(x, prec, rnd=round_fast): return mpf_cos_sin(x, prec, rnd, 2)
#
# File ~/Library/Python/3.8/lib/python/site-packages/mpmath/libmp/libelefun.py:1360, in mpf_cos_sin(x, prec, rnd, which, pi)
#    1358 else:
#    1359     t, n, wp = mod_pi2(man, exp, mag, wp)
# -> 1360 c, s = cos_sin_basecase(t, wp)
#    1361 m = n & 3
#    1362 if   m == 1: c, s = -s, c
#
# File ~/Library/Python/3.8/lib/python/site-packages/mpmath/libmp/libelefun.py:1148, in cos_sin_basecase(x, prec)
#    1146 while a:
#    1147     a //= k; cos += a; k += 1; a = (a*x) >> prec
# -> 1148     a //= k; sin += a; k += 1; a = -((a*x) >> prec)
#    1149 return ((cos*cos_t-sin*sin_t) >> prec), ((sin*cos_t+cos*sin_t) >> prec)
#
# KeyboardInterrupt:
